# %%
import pandas as pd

# %%
data = pd.read_csv('nigerian_spotify_songs1.csv')
print(data.shape)
data.head()
# Out:
# (530, 16)
#                        name                         album  \
# 0                    Sparky            Mandy & The Jungle
# 1                shuga rush  EVERYTHING YOU HEARD IS TRUE
# 2                     LITT!                         LITT!
# 3  Confident / Feeling Cool               Enjoy Your Life
# 4                wanted you                         rare.
#
#                 artist artist_top_genre  release_date  length  popularity  \
# 0        Cruel Santino  alternative r&b          2019  144000          48
# 1  Odunsi (The Engine)          afropop          2020   89488          30
# 2                 AYLØ        indie r&b          2018  207758          40
# 3           Lady Donli     nigerian pop          2019  175135          14
# 4  Odunsi (The Engine)          afropop          2018  152049          25
#
#    danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0         0.666        0.8510   0.420          0.534000    0.1100    -6.699
# ...

# %%
data.artist.values#value_counts()
# Out:
# array(['Cruel Santino', 'Odunsi (The Engine)', 'AYLØ', 'Lady Donli',
#        'Odunsi (The Engine)', 'DRB Lasgidi', 'prettyboydo',
#        'Odunsi (The Engine)', 'Lady Donli', 'Tay Iwar', 'Cruel Santino',
#        'Odunsi (The Engine)', 'Cruel Santino', 'prettyboydo',
#        'Cruel Santino', 'Lady Donli', 'AYLØ', 'Odunsi (The Engine)',
#        'Cruel Santino', 'Amaarae', 'Odunsi (The Engine)', 'AYLØ',
#        'Lady Donli', 'Odunsi (The Engine)', 'Lady Donli', 'AYLØ',
#        'Odunsi (The Engine)', 'Lady Donli', 'Tay Iwar', 'DRB Lasgidi',
#        'Joeboy', 'DaVido', 'Joeboy', 'DaVido', 'Bracket', 'DJ Neptune',
#        'Sean Tizzle', 'Teni', 'KiDi', 'T-Classic', 'Simi', 'Runtown',
#        'KiDi', 'WizKid', 'Patoranking', 'P-Square', 'DaVido', 'Stormrex',
#        'chike', 'Chidinma', 'KiDi', 'Banky W.', 'Phyno', 'Tekno',
#        'Mayorkun', 'Peruzzi', 'Kiss Daniel', 'DaVido', 'WizKid',
#        'Korede Bello', 'DMW', 'Bracket', 'Kizz Daniel', 'L.A.X', 'E.L',
# ...
